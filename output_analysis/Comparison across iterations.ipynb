# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %%
BASE_DIR = Path.cwd()

# %%
BASE_DIR.parent
# Out:
# WindowsPath('E:/GitHub/beam')

# %%
rootPath = BASE_DIR.parent.joinpath("output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-8__bgb/ITERS")
rootPath
# Out:
# WindowsPath('E:/GitHub/beam/output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-8__bgb/ITERS')

# %%
null_modes=pd.read_csv('Temp/null_modes.csv')
null_mode_agents=null_modes.personId.unique()[0:5]

# %%
null_mode_agents
# Out:
# array(['63-3', '63-7', '131-2', '320-1', 'ix-320-2'], dtype=object)

# %%
plans_iter_0=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.0/0.plans.csv.gz')
plans_iter_0=plans_iter_0[plans_iter_0['personId'].isin(null_mode_agents)]


plans_iter_1=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.1/1.plans.csv.gz')
plans_iter_1=plans_iter_1[plans_iter_1['personId'].isin(null_mode_agents)]

plans_iter_2=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.2/2.plans.csv.gz')
plans_iter_2=plans_iter_2[plans_iter_2['personId'].isin(null_mode_agents)]

plans_iter_3=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.3/3.plans.csv.gz')
plans_iter_3=plans_iter_3[plans_iter_3['personId'].isin(null_mode_agents)]

plans_iter_4=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.4/4.plans.csv.gz')
plans_iter_4=plans_iter_4[plans_iter_4['personId'].isin(null_mode_agents)]

plans_iter_5=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.5/5.plans.csv.gz')
plans_iter_5=plans_iter_5[plans_iter_5['personId'].isin(null_mode_agents)]

plans_iter_6=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.6/6.plans.csv.gz')
plans_iter_6=plans_iter_6[plans_iter_6['personId'].isin(null_mode_agents)]

plans_iter_7=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.7/7.plans.csv.gz')
plans_iter_7=plans_iter_7[plans_iter_7['personId'].isin(null_mode_agents)]

plans_iter_8=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.8/8.plans.csv.gz')
plans_iter_8=plans_iter_8[plans_iter_8['personId'].isin(null_mode_agents)]

plans_iter_9=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.9/9.plans.csv.gz')
plans_iter_9=plans_iter_9[plans_iter_9['personId'].isin(null_mode_agents)]

plans_iter_10=pd.read_csv('../output/SF_TourPurposeChoiceModel/sf-tscore-all-trips-mc-calibration-trial-with-null-modes_only__ayy/ITERS/it.10/10.plans.csv.gz')
plans_iter_10=plans_iter_10[plans_iter_10['personId'].isin(null_mode_agents)]

# %%
def plans_cleanup(plans):
    
    
    plans['Mode']=plans['legMode'].shift(-1)
    plans['maxPlanElementIndex']=plans.groupby('personId')['planElementIndex'].transform(max)
    
    
    plans['origin_activityType']=plans['activityType']
    plans['destination_activityType']=plans['activityType'].shift(-2)
    
    
    plans['legTravelTime']=plans['legTravelTime'].shift(-1)
    plans['legDepartureTime']=plans['legDepartureTime'].shift(-1)
    
    plans=plans[plans['planElementIndex']!=plans['maxPlanElementIndex']]
    
    plans_df=plans[plans['activityType'].notnull()]

    return plans_df[['personId', 'planIndex', 'planScore', 'planSelected', 'planElementType',
       'planElementIndex', 'activityEndTime', 'legDepartureTime',
       'legTravelTime', 'Mode',
       'maxPlanElementIndex', 'origin_activityType',
       'destination_activityType']]

# %%
plans_iter_0.columns
# Out:
# Index(['personId', 'planIndex', 'planScore', 'planSelected', 'planElementType',
#        'planElementIndex', 'activityType', 'activityLocationX',
#        'activityLocationY', 'activityEndTime', 'legMode', 'legDepartureTime',
#        'legTravelTime', 'legRouteType', 'legRouteStartLink', 'legRouteEndLink',
#        'legRouteTravelTime', 'legRouteDistance', 'legRouteLinks'],
#       dtype='object')

# %%
plans_0=plans_cleanup(plans_iter_0)
plans_1=plans_cleanup(plans_iter_1)
plans_2=plans_cleanup(plans_iter_2)
plans_3=plans_cleanup(plans_iter_3)
plans_4=plans_cleanup(plans_iter_4)
plans_5=plans_cleanup(plans_iter_5)
plans_6=plans_cleanup(plans_iter_6)
plans_7=plans_cleanup(plans_iter_7)
plans_8=plans_cleanup(plans_iter_8)
plans_9=plans_cleanup(plans_iter_9)
plans_10=plans_cleanup(plans_iter_10)

# %%
plans_iter_0[plans_iter_0['personId']=='63-3']
# Out:
#    personId  planIndex  planScore  planSelected  \
# 0      63-3          0  609.08463          True
# 1      63-3          0  609.08463          True
# 2      63-3          0  609.08463          True
# 3      63-3          0  609.08463          True
# 4      63-3          0  609.08463          True
# 5      63-3          0  609.08463          True
# 6      63-3          0  609.08463          True
# 7      63-3          0  609.08463          True
# 8      63-3          0  609.08463          True
# 9      63-3          0  609.08463          True
# 10     63-3          0  609.08463          True
# 11     63-3          0  609.08463          True
# 12     63-3          0  609.08463          True
# 13     63-3          0  609.08463          True
# 14     63-3          0  609.08463          True
# 15     63-3          0  609.08463          True
# 16     63-3          0  609.08463          True
#
#                                       planElementType  planElementIndex  \
# ...

# %%
plans_0[plans_0['personId']=='63-3']
# Out:
#    personId  planIndex  planScore  planSelected  \
# 0      63-3          0  609.08463          True
# 2      63-3          0  609.08463          True
# 4      63-3          0  609.08463          True
# 6      63-3          0  609.08463          True
# 8      63-3          0  609.08463          True
# 10     63-3          0  609.08463          True
# 12     63-3          0  609.08463          True
# 14     63-3          0  609.08463          True
#
#                                       planElementType  planElementIndex  \
# 0   beam.utils.scenario.PlanElement$Activity$@1c54...                 0
# 2   beam.utils.scenario.PlanElement$Activity$@1c54...                 2
# 4   beam.utils.scenario.PlanElement$Activity$@1c54...                 4
# 6   beam.utils.scenario.PlanElement$Activity$@1c54...                 6
# 8   beam.utils.scenario.PlanElement$Activity$@1c54...                 8
# 10  beam.utils.scenario.PlanElement$Activity$@1c54...                10
# ...
